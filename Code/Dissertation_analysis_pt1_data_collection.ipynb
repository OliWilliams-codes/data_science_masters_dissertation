# %% [markdown]
# # Notebook Overview
#
# This notebook focuses on handling and visualizing Statsbomb event data, specifically for public data related to soccer matches. The main steps include:
#
# 1.  **Configuration**: Setting up the environment by installing necessary libraries.
# 2.  **Data Loading and Filtering**: Retrieving competition and match data from the Statsbomb API and filtering it based on specific criteria (e.g., gender, age, year, season).
# 3.  **Retrieving and Processing Event Data**: Obtaining detailed event data for the selected matches, handling it in chunks, and performing initial data wrangling.
# 4.  **Analyzing Event Data**: Analyzing different types of events (Duels, 50/50s, Dispossessed, Foul Committed, Foul Won) and calculating relevant metrics like sequence length and passes in sequence.
# 5.  **Combining Event Data**: Merging the analyzed data from different event types into a single DataFrame.
# 6.  **Saving the Combined Data**: Saving the final processed data to Google Drive for further use.
#
# This notebook aims to provide a foundation for exploring and visualizing soccer event data from Statsbomb.

# %% [markdown]
# # Introduction

# %% [markdown]
# Handle Statsbomb event data and explore visualization with public data.

# %% [markdown]
# # Configuration

# %%
# !pip install statsbombpy
# Out:
# Requirement already satisfied: statsbombpy in /usr/local/lib/python3.12/dist-packages (1.16.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from statsbombpy) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from statsbombpy) (2.32.3)
# Requirement already satisfied: requests-cache in /usr/local/lib/python3.12/dist-packages (from statsbombpy) (1.2.1)
# Requirement already satisfied: inflect in /usr/local/lib/python3.12/dist-packages (from statsbombpy) (7.5.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from statsbombpy) (1.5.1)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.12/dist-packages (from inflect->statsbombpy) (10.7.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from inflect->statsbombpy) (4.4.4)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->statsbombpy) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->statsbombpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->statsbombpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->statsbombpy) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->statsbombpy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->statsbombpy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->statsbombpy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->statsbombpy) (2025.8.3)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache->statsbombpy) (25.3.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache->statsbombpy) (25.1.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache->statsbombpy) (4.3.8)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.12/dist-packages (from requests-cache->statsbombpy) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache->statsbombpy) (4.14.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->statsbombpy) (1.17.0)

# %%
import pandas as pd
from statsbombpy import sb

# %%
a=0
b=1

# %% [markdown]
# The statsbombpy automatically interact with repository. For more details you can access to github.

# %% [markdown]
# https://github.com/statsbomb/open-data

# %% [markdown]
# Data Loading and Filtering
#
# This section focuses on loading the necessary data from the Statsbomb API and filtering it to include only relevant competitions and matches for analysis.
#
# First, we retrieve a list of all available competitions from Statsbomb. We then filter this list to include only male, non-international, non-youth competitions from the year 2000 onwards.
#
# Next, we retrieve all matches for the filtered competitions and concatenate them into a single DataFrame. Finally, we filter these matches further to focus on the 2015/2016 season and exclude Champions League matches, as per the project's requirements.

# %%
df_competitions = sb.competitions()
df_competitions.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
# 3              16          4       Europe        Champions League
# 4              16          1       Europe        Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                       True
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated           match_updated_360  \
# 0   2023/2024  2024-09-28T20:46:38.893391  2025-07-06T04:26:07.636270
# 1   2015/2016  2024-05-19T11:11:14.192381                        None
# 2        2023  2024-09-28T01:57:35.846538                        None
# 3   2018/2019  2025-05-08T15:10:50.835274     2021-06-13T16:17:31.694
# 4   2017/2018  2024-02-13T02:35:28.134882     2021-06-13T16:17:31.694
#
#           match_available_360             match_available
# 0  2025-07-06T04:26:07.636270  2024-09-28T20:46:38.893391
# 1                        None  2024-05-19T11:11:14.192381
# 2                        None  2024-09-28T01:57:35.846538
# 3                        None  2025-05-08T15:10:50.835274
# 4                        None  2024-02-13T02:35:28.134882

# %%
df_competitions['season_year'] = df_competitions['season_name'].str[-4:].astype(int)
df_competitions_filtered = df_competitions[
    (df_competitions['season_year'] > 2000) &
    (df_competitions['competition_international'] == False) &
    (df_competitions['competition_youth'] == False) &
    (df_competitions['competition_gender'] == 'male')
]
df_competitions_filtered
# Out:
#     competition_id  season_id              country_name     competition_name  \
# 0                9        281                   Germany        1. Bundesliga
# 1                9         27                   Germany        1. Bundesliga
# 3               16          4                    Europe     Champions League
# 4               16          1                    Europe     Champions League
# 5               16          2                    Europe     Champions League
# 6               16         27                    Europe     Champions League
# 7               16         26                    Europe     Champions League
# 8               16         25                    Europe     Champions League
# 9               16         24                    Europe     Champions League
# 10              16         23                    Europe     Champions League
# 11              16         22                    Europe     Champions League
# 12              16         21                    Europe     Champions League
# 13              16         41                    Europe     Champions League
# 14              16         39                    Europe     Champions League
# 15              16         37                    Europe     Champions League
# 16              16         44                    Europe     Champions League
# 37            1238        108                     India  Indian Super league
# 38              11         90                     Spain              La Liga
# 39              11         42                     Spain              La Liga
# 40              11          4                     Spain              La Liga
# 41              11          1                     Spain              La Liga
# 42              11          2                     Spain              La Liga
# 43              11         27                     Spain              La Liga
# 44              11         26                     Spain              La Liga
# 45              11         25                     Spain              La Liga
# 46              11         24                     Spain              La Liga
# 47              11         23                     Spain              La Liga
# 48              11         22                     Spain              La Liga
# 49              11         21                     Spain              La Liga
# 50              11         41                     Spain              La Liga
# 51              11         40                     Spain              La Liga
# 52              11         39                     Spain              La Liga
# 53              11         38                     Spain              La Liga
# 54              11         37                     Spain              La Liga
# 58               7        235                    France              Ligue 1
# 59               7        108                    France              Ligue 1
# 60               7         27                    France              Ligue 1
# 61              44        107  United States of America  Major League Soccer
# 64               2         27                   England       Premier League
# 65               2         44                   England       Premier League
# 66              12         27                     Italy              Serie A
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# 1                male              False                      False
# 3                male              False                      False
# 4                male              False                      False
# 5                male              False                      False
# 6                male              False                      False
# 7                male              False                      False
# 8                male              False                      False
# 9                male              False                      False
# 10               male              False                      False
# 11               male              False                      False
# 12               male              False                      False
# 66                        None  2025-07-21T05:01:00.434081         2016

# %%
all_matches = []
for index, row in df_competitions_filtered.iterrows():
    competition_id = row['competition_id']
    season_id = row['season_id']
    try:
        df_matches = sb.matches(competition_id=competition_id, season_id=season_id)
        all_matches.append(df_matches)
    except Exception as e:
        print(f"Could not retrieve matches for competition_id: {competition_id}, season_id: {season_id}. Error: {e}")

if all_matches:
    df_all_matches = pd.concat(all_matches, ignore_index=True)
    print(df_all_matches.head())
else:
    print("No matches data retrieved.")


df_all_matches
# Out:
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    match_id  match_date      kick_off              competition     season  \
# 0   3895302  2024-04-14  17:30:00.000  Germany - 1. Bundesliga  2023/2024
# 1   3895292  2024-04-06  15:30:00.000  Germany - 1. Bundesliga  2023/2024
# 2   3895333  2024-05-05  18:30:00.000  Germany - 1. Bundesliga  2023/2024
# 3   3895340  2024-05-12  20:30:00.000  Germany - 1. Bundesliga  2023/2024
# 4   3895348  2024-05-18  16:30:00.000  Germany - 1. Bundesliga  2023/2024
#
#              home_team         away_team  home_score  away_score match_status  \
# 0     Bayer Leverkusen     Werder Bremen           5           0    available
# 1         Union Berlin  Bayer Leverkusen           0           1    available
# 2  Eintracht Frankfurt  Bayer Leverkusen           1           5    available
# 3               Bochum  Bayer Leverkusen           0           5    available
# 4     Bayer Leverkusen          Augsburg           2           1    available
#
#    ...            last_updated_360 match_week competition_stage  \
# 0  ...  2024-05-10T17:03:59.613154         29    Regular Season
# 1  ...  2024-05-12T21:08:37.897296         28    Regular Season
# 2  ...  2024-05-14T16:32:13.483516         32    Regular Season
# 3  ...  2024-05-14T16:46:08.459843         33    Regular Season
# 4  ...  2024-05-20T10:33:09.140760         34    Regular Season
#
#                           stadium              referee        home_managers  \
# 0                        BayArena          Harm Osmers  Xabier Alonso Olano
# 1  Stadion An der Alten Försterei       Benjamin Brand        Nenad Bjelica
# 2              Deutsche Bank Park    Christian Dingert      Dino Toppmöller
# 3             Vonovia Ruhrstadion       Benjamin Brand       Heiko Butscher
# 4                        BayArena  Matthias Jöllenbeck  Xabier Alonso Olano
#
#            away_managers data_version shot_fidelity_version  \
# 0             Ole Werner        1.1.0                     2
# 1    Xabier Alonso Olano        1.1.0                     2
# 2    Xabier Alonso Olano        1.1.0                     2
# 3    Xabier Alonso Olano        1.1.0                     2
# 4  Jess Christian Thorup        1.1.0                     2
#
#   xy_fidelity_version
# 0                   2
# 1                   2
# 2                   2
# 3                   2
# 4                   2
#
# [5 rows x 22 columns]
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#       match_id  match_date      kick_off              competition     season  \
# 0      3895302  2024-04-14  17:30:00.000  Germany - 1. Bundesliga  2023/2024
# 1      3895292  2024-04-06  15:30:00.000  Germany - 1. Bundesliga  2023/2024
# 2      3895333  2024-05-05  18:30:00.000  Germany - 1. Bundesliga  2023/2024
# 3      3895340  2024-05-12  20:30:00.000  Germany - 1. Bundesliga  2023/2024
# 4      3895348  2024-05-18  16:30:00.000  Germany - 1. Bundesliga  2023/2024
# ...        ...         ...           ...                      ...        ...
# 2570   3878544  2015-08-23  20:45:00.000          Italy - Serie A  2015/2016
# 2571   3878543  2015-08-23  20:45:00.000          Italy - Serie A  2015/2016
# 2572   3878542  2015-08-23  20:45:00.000          Italy - Serie A  2015/2016
# 2573   3878541  2015-08-22  18:00:00.000          Italy - Serie A  2015/2016
# 2574   3878540  2015-08-22  20:45:00.000          Italy - Serie A  2015/2016
#
#                 home_team         away_team  home_score  away_score  \
# 0        Bayer Leverkusen     Werder Bremen           5           0
# 1            Union Berlin  Bayer Leverkusen           0           1
# 2     Eintracht Frankfurt  Bayer Leverkusen           1           5
# 3                  Bochum  Bayer Leverkusen           0           5
# 4        Bayer Leverkusen          Augsburg           2           1
# ...                   ...               ...         ...         ...
# 2570              Palermo             Genoa           1           0
# 2571          Inter Milan          Atalanta           1           0
# 2572           Fiorentina          AC Milan           2           0
# 2573        Hellas Verona           AS Roma           1           1
# 2574                Lazio           Bologna           2           1
#
#      match_status  ...            last_updated_360 match_week  \
# 0       available  ...  2024-05-10T17:03:59.613154         29
# 1       available  ...  2024-05-12T21:08:37.897296         28
# 2       available  ...  2024-05-14T16:32:13.483516         32
# 3       available  ...  2024-05-14T16:46:08.459843         33
# 4       available  ...  2024-05-20T10:33:09.140760         34
# ...           ...  ...                         ...        ...
# 2570    available  ...                        None          1
# 2571    available  ...                        None          1
# 2572    available  ...                        None          1
# 2573    available  ...                        None          1
# 2574    available  ...                        None          1
#
#      competition_stage                         stadium                referee  \
# 0       Regular Season                        BayArena            Harm Osmers
# 1       Regular Season  Stadion An der Alten Försterei         Benjamin Brand
# 2       Regular Season              Deutsche Bank Park      Christian Dingert
# 3       Regular Season             Vonovia Ruhrstadion         Benjamin Brand
# 4       Regular Season                        BayArena    Matthias Jöllenbeck
# ...                ...                             ...                    ...
# 2570    Regular Season            Stadio Renzo Barbera    Massimiliano Irrati
# 2571    Regular Season      Stadio Giuseppe Meazza      Gianpaolo Calvarese\t
# 2572    Regular Season    Stadio Artemio Franchi    \t           Paolo Valeri
# 2573    Regular Season  Stadio Marc''Antonio Bentegodi            Marco Guida
# 2574    Regular Season                Estadio Olímpico        Gianluca Rocchi
#
#                                   home_managers          away_managers  \
# 0                           Xabier Alonso Olano             Ole Werner
# 1                                 Nenad Bjelica    Xabier Alonso Olano
# 2                               Dino Toppmöller    Xabier Alonso Olano
# 3                                Heiko Butscher    Xabier Alonso Olano
# 4                           Xabier Alonso Olano  Jess Christian Thorup
# ...                                         ...                    ...
# 2570                           Giuseppe Iachini   Gian Piero Gasperini
# 2571                            Roberto Mancini           Edoardo Reja
# 2572             Paulo Manuel Carvalho de Sousa      Siniša Mihajlović
# 2573  Rafael Márquez Álvarez, Andrea Mandorlini            Rudi Garcia
# 2574                              Stefano Pioli            Delio Rossi
#
#      data_version shot_fidelity_version xy_fidelity_version
# 0           1.1.0                     2                   2
# 1           1.1.0                     2                   2
# 2           1.1.0                     2                   2
# 3           1.1.0                     2                   2
# 4           1.1.0                     2                   2
# ...           ...                   ...                 ...
# 2570        1.1.0                     2                   2
# 2571        1.1.0                     2                   2
# 2572        1.1.0                     2                   2
# 2573        1.1.0                     2                   2
# 2574         None                  None                None
#
# [2575 rows x 22 columns]

# %%
df_filtered_matches = df_all_matches[
    (df_all_matches['season']=='2015/2016') &
    (df_all_matches['competition'] != 'Europe - Champions League')
].copy()
print(df_filtered_matches.head())
# Out:
#     match_id  match_date      kick_off              competition     season  \
# 34   3890561  2016-05-14  15:30:00.000  Germany - 1. Bundesliga  2015/2016
# 35   3890505  2016-04-02  15:30:00.000  Germany - 1. Bundesliga  2015/2016
# 36   3890511  2016-04-08  20:30:00.000  Germany - 1. Bundesliga  2015/2016
# 37   3890515  2016-04-09  15:30:00.000  Germany - 1. Bundesliga  2015/2016
# 38   3890411  2015-12-20  16:30:00.000  Germany - 1. Bundesliga  2015/2016
#
#         home_team            away_team  home_score  away_score match_status  \
# 34     Hoffenheim           Schalke 04           1           4    available
# 35  Bayern Munich  Eintracht Frankfurt           1           0    available
# 36  Hertha Berlin          Hannover 96           2           2    available
# 37   Hamburger SV         Darmstadt 98           1           2    available
# 38  Hertha Berlin         FSV Mainz 05           2           0    available
#
#     ... last_updated_360 match_week competition_stage                stadium  \
# 34  ...             None         34    Regular Season          PreZero Arena
# 35  ...             None         28    Regular Season          Allianz Arena
# 36  ...             None         29    Regular Season  Olympiastadion Berlin
# 37  ...             None         29    Regular Season       Volksparkstadion
# 38  ...             None         17    Regular Season  Olympiastadion Berlin
#
#            referee           home_managers        away_managers data_version  \
# 34     Felix Brych       Julian Nagelsmann  André Breitenreiter        1.1.0
# 35   Florian Meyer  Josep Guardiola i Sala           Niko Kovač        1.1.0
# 36  Benjamin Brand              Pál Dárdai       Daniel Stendel        1.1.0
# 37    Peter Sippel          Bruno Labbadia        Dirk Schuster        1.1.0
# 38    Peter Sippel              Pál Dárdai       Martin Schmidt        1.1.0
#
#    shot_fidelity_version xy_fidelity_version
# 34                     2                   2
# 35                     2                   2
# 36                     2                   2
# 37                     2                   2
# 38                     2                   2
#
# [5 rows x 22 columns]

# %%
df_selected_cols = df_filtered_matches[['competition', 'match_id','season']]

# %%
df_2015_2016 = df_filtered_matches[df_filtered_matches['season'] == '2015/2016'].copy()

# Group by competition and list match_ids
competition_match_ids = df_2015_2016.groupby('competition')['match_id'].apply(list)

competition_match_ids
# Out:
# competition
# England - Premier League    [3754058, 3754245, 3754136, 3754037, 3754039, ...
# France - Ligue 1            [3901199, 3901178, 3901260, 3829470, 3901259, ...
# Germany - 1. Bundesliga     [3890561, 3890505, 3890511, 3890515, 3890411, ...
# Italy - Serie A             [3879863, 3879773, 3879847, 3879862, 3879817, ...
# Spain - La Liga             [3825848, 3825895, 3825894, 3825855, 3825908, ...
# Name: match_id, dtype: object

# %%
df_wwc = df_filtered_matches.copy()

# %%
matchids=df_wwc['match_id'].unique()
print(matchids)
# Out:
# [3890561 3890505 3890511 ... 3878542 3878541 3878540]

# %%
# Group match ids into chunks
chunk_size = 250
match_id_chunks = [matchids[i:i + chunk_size] for i in range(0, len(matchids), chunk_size)]

# Print the names of each group (by index)
for i, chunk in enumerate(match_id_chunks):
  print(f"Group {i+1}")
  # If you want to see the match ids in each group, uncomment the line below
  print(chunk)
# Out:
# Group 1
# [3890561 3890505 3890511 3890515 3890411 3890397 3890401 3890396 3890384
#
# After retrieving the event data, we concatenate it into a single DataFrame and perform some initial data wrangling steps, such as extracting location coordinates and creating a unique identifier for each possession.

# %%
# Select the first chunk of match IDs
match_ids_chunk_1 = match_id_chunks[a]

# Retrieve events for the matches in the first chunk
all_events_chunk_1 = []
for match_id in match_ids_chunk_1:
  try:
    df_events = sb.events(match_id=match_id)
    all_events_chunk_1.append(df_events)
  except Exception as e:
    print(f"Could not retrieve events for match_id: {match_id}. Error: {e}")

# Concatenate the events dataframes from the first chunk
if all_events_chunk_1:
  df_all_events_chunk_1 = pd.concat(all_events_chunk_1, ignore_index=True)
  print(df_all_events_chunk_1.head())
else:
  print("No events data retrieved for the first chunk of matches.")

# Display the dataframe
df_all_events_chunk_1
# Out:
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#   ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 0                  NaN                            NaN              NaN
# 1                  NaN                            NaN              NaN
# 2                  NaN                            NaN              NaN
# 3                  NaN                            NaN              NaN
# 4                  NaN                            NaN              NaN
#
#   carry_end_location clearance_aerial_won clearance_body_part clearance_head  \
# 0                NaN                  NaN                 NaN            NaN
# 1                NaN                  NaN                 NaN            NaN
# 2                NaN                  NaN                 NaN            NaN
# 3                NaN                  NaN                 NaN            NaN
# 4                NaN                  NaN                 NaN            NaN
#
#   clearance_left_foot clearance_right_foot counterpress  ... block_save_block  \
# 0                 NaN                  NaN          NaN  ...              NaN
# 1                 NaN                  NaN          NaN  ...              NaN
# 2                 NaN                  NaN          NaN  ...              NaN
# 3                 NaN                  NaN          NaN  ...              NaN
# 4                 NaN                  NaN          NaN  ...              NaN
#
#   goalkeeper_punched_out shot_redirect goalkeeper_shot_saved_off_target  \
# 0                    NaN           NaN                              NaN
# 1                    NaN           NaN                              NaN
# 2                    NaN           NaN                              NaN
# 3                    NaN           NaN                              NaN
# 4                    NaN           NaN                              NaN
#
#   shot_saved_off_target  goalkeeper_shot_saved_to_post shot_saved_to_post  \
# 0                   NaN                            NaN                NaN
# 1                   NaN                            NaN                NaN
# 2                   NaN                            NaN                NaN
# 3                   NaN                            NaN                NaN
# 4                   NaN                            NaN                NaN
#
#   goalkeeper_lost_out goalkeeper_success_in_play shot_follows_dribble
# 0                 NaN                        NaN                  NaN
# 1                 NaN                        NaN                  NaN
# 2                 NaN                        NaN                  NaN
# 3                 NaN                        NaN                  NaN
# 4                 NaN                        NaN                  NaN
#
# [5 rows x 114 columns]
#        ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 0                       NaN                            NaN              NaN
# 1                       NaN                            NaN              NaN
# 2                       NaN                            NaN              NaN
# 3                       NaN                            NaN              NaN
# 4                       NaN                            NaN              NaN
# ...                     ...                            ...              ...
# 879717                  NaN                            NaN              NaN
# 879718                  NaN                            NaN              NaN
# 879719                  NaN                            NaN              NaN
# 879720                  NaN                            NaN              NaN
# 879721                  NaN                            NaN              NaN
#
#        carry_end_location clearance_aerial_won clearance_body_part  \
# 0                     NaN                  NaN                 NaN
# 1                     NaN                  NaN                 NaN
# 2                     NaN                  NaN                 NaN
# 3                     NaN                  NaN                 NaN
# 4                     NaN                  NaN                 NaN
# ...                   ...                  ...                 ...
# 879717                NaN                  NaN                 NaN
# 879718                NaN                  NaN                 NaN
# 879719                NaN                  NaN                 NaN
# 879720                NaN                  NaN                 NaN
# 879721                NaN                  NaN                 NaN
#
#        clearance_head clearance_left_foot clearance_right_foot counterpress  \
# 0                 NaN                 NaN                  NaN          NaN
# 1                 NaN                 NaN                  NaN          NaN
# 2                 NaN                 NaN                  NaN          NaN
# 3                 NaN                 NaN                  NaN          NaN
# 4                 NaN                 NaN                  NaN          NaN
# ...               ...                 ...                  ...          ...
# 879717            NaN                 NaN                  NaN          NaN
# 879718            NaN                 NaN                  NaN          NaN
# 879719            NaN                 NaN                  NaN          NaN
# 879720            NaN                 NaN                  NaN          NaN
# 879721            NaN                 NaN                  NaN          NaN
#
#         ... block_save_block goalkeeper_punched_out shot_redirect  \
# 0       ...              NaN                    NaN           NaN
# 1       ...              NaN                    NaN           NaN
# 2       ...              NaN                    NaN           NaN
# 3       ...              NaN                    NaN           NaN
# 4       ...              NaN                    NaN           NaN
# ...     ...              ...                    ...           ...
# 879717  ...              NaN                    NaN           NaN
# 879718  ...              NaN                    NaN           NaN
# 879719  ...              NaN                    NaN           NaN
# 879720  ...              NaN                    NaN           NaN
# 879721  ...              NaN                    NaN           NaN
#
#        goalkeeper_shot_saved_off_target shot_saved_off_target  \
# 0                                   NaN                   NaN
# 1                                   NaN                   NaN
# 2                                   NaN                   NaN
# 3                                   NaN                   NaN
# 4                                   NaN                   NaN
# ...                                 ...                   ...
# 879717                              NaN                   NaN
# 879718                              NaN                   NaN
# 879719                              NaN                   NaN
# 879720                              NaN                   NaN
# 879721                              NaN                   NaN
#
#         goalkeeper_shot_saved_to_post shot_saved_to_post goalkeeper_lost_out  \
# 0                                 NaN                NaN                 NaN
# 1                                 NaN                NaN                 NaN
# 2                                 NaN                NaN                 NaN
# 3                                 NaN                NaN                 NaN
# 4                                 NaN                NaN                 NaN
# ...                               ...                ...                 ...
# 879717                            NaN                NaN                 NaN
# 879718                            NaN                NaN                 NaN
# 879719                            NaN                NaN                 NaN
# 879720                            NaN                NaN                 NaN
# 879721                            NaN                NaN                 NaN
#
#        goalkeeper_success_in_play shot_follows_dribble
# 0                             NaN                  NaN
# 1                             NaN                  NaN
# 2                             NaN                  NaN
# 3                             NaN                  NaN
# 4                             NaN                  NaN
# ...                           ...                  ...
# 879717                        NaN                  NaN
# 879718                        NaN                  NaN
# 879719                        NaN                  NaN
# 879720                        NaN                  NaN
# 879721                        NaN                  NaN
#
# [879722 rows x 114 columns]

# %%
df_final_matches = df_all_events_chunk_1

# %%
df_final_matches = pd.merge(df_final_matches, df_wwc[['match_id', 'home_team']], on='match_id', how='left')

# %%
df_final_matches['home_team_flag'] = (df_final_matches['possession_team'] == df_final_matches['home_team']).astype(int)

# %%
df_final_matches[['x','y']] = df_final_matches['location'].apply(pd.Series)

# %%
df_final_matches['new_id'] = df_final_matches['match_id'].astype(str) + '_' + df_final_matches['possession'].astype(str)
df_first_event_of_possession = df_final_matches.loc[df_final_matches.groupby('new_id')['index'].idxmin()]

# %%
print(df_final_matches['type'].unique())
# Out:
# ['Starting XI' 'Half Start' 'Pass' 'Ball Receipt*' 'Carry' 'Pressure'
#  'Block' 'Ball Recovery' 'Miscontrol' 'Interception' 'Foul Committed'
#  'Foul Won' 'Shot' 'Goal Keeper' 'Duel' 'Dribble' 'Dribbled Past'
#  'Clearance' 'Dispossessed' 'Tactical Shift' 'Injury Stoppage'
#  'Player Off' 'Player On' 'Half End' 'Substitution' 'Shield'
#  'Own Goal Against' 'Own Goal For' '50/50' 'Referee Ball-Drop'
#  'Bad Behaviour' 'Offside' 'Error']

# %%
new_dfs = {}
for event_type in df_final_matches['type'].unique():
  df_name = f"df_{event_type.replace(' ', '_').lower()}"
  new_dfs[df_name] = df_final_matches[df_final_matches['type'] == event_type].copy()

print("List of new dataframes:")
for df_name in new_dfs.keys():
    # Indent this line to be inside the loop and use print() to display the name
    print(df_name)

# You can access a specific dataframe like this:
df_carry = new_dfs['df_carry']
print(df_carry.head())
# Out:
# List of new dataframes:
# df_starting_xi
# df_half_start
# df_pass
# df_ball_receipt*
# df_carry
# df_pressure
# df_block
# df_ball_recovery
# df_miscontrol
# df_interception
# df_foul_committed
# df_foul_won
# df_shot
# df_goal_keeper
# df_duel
# df_dribble
# df_dribbled_past
# df_clearance
# df_dispossessed
# df_tactical_shift
# df_injury_stoppage
# df_player_off
# df_player_on
# df_half_end
# df_substitution
# df_shield
# df_own_goal_against
# df_own_goal_for
# df_50/50
# df_referee_ball-drop
# df_bad_behaviour
# df_offside
# df_error
#      ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 2165                  NaN                            NaN              NaN
# 2166                  NaN                            NaN              NaN
# 2167                  NaN                            NaN              NaN
# 2168                  NaN                            NaN              NaN
# 2169                  NaN                            NaN              NaN
#
#      carry_end_location clearance_aerial_won clearance_body_part  \
# 2165       [59.4, 38.3]                  NaN                 NaN
# 2166       [52.3, 45.2]                  NaN                 NaN
# 2167       [34.3, 61.9]                  NaN                 NaN
# 2168       [38.5, 22.2]                  NaN                 NaN
# 2169       [39.6, 32.7]                  NaN                 NaN
#
#      clearance_head clearance_left_foot clearance_right_foot counterpress  \
# 2165            NaN                 NaN                  NaN          NaN
# 2166            NaN                 NaN                  NaN          NaN
# 2167            NaN                 NaN                  NaN          NaN
# 2168            NaN                 NaN                  NaN          NaN
# 2169            NaN                 NaN                  NaN          NaN
#
#       ... goalkeeper_shot_saved_to_post shot_saved_to_post  \
# 2165  ...                           NaN                NaN
# 2166  ...                           NaN                NaN
# 2167  ...                           NaN                NaN
# 2168  ...                           NaN                NaN
# 2169  ...                           NaN                NaN
#
#      goalkeeper_lost_out goalkeeper_success_in_play shot_follows_dribble  \
# 2165                 NaN                        NaN                  NaN
# 2166                 NaN                        NaN                  NaN
# 2167                 NaN                        NaN                  NaN
# 2168                 NaN                        NaN                  NaN
# 2169                 NaN                        NaN                  NaN
#
#        home_team home_team_flag     x     y     new_id
# 2165  Hoffenheim              1  60.2  37.9  3890561_2
# 2166  Hoffenheim              1  53.9  42.1  3890561_2
# 2167  Hoffenheim              1  34.3  62.0  3890561_2
# 2168  Hoffenheim              1  37.5  23.7  3890561_2
# 2169  Hoffenheim              1  36.7  35.5  3890561_2
#
# [5 rows x 119 columns]

# %% [markdown]
# **High Level**

# %%
match_analysis = df_final_matches.groupby('match_id').agg(
    duration=('duration', 'sum'),
    xg=('shot_statsbomb_xg', 'sum'),
    home_team_duration=('duration', lambda x: x[df_final_matches.loc[x.index, 'home_team_flag'] == 1].sum()),
    max_posession=('possession', 'max')
).reset_index()

# Calculate the shot_home_proportion after aggregation
match_analysis['home_team_duration'] = match_analysis['home_team_duration'] / match_analysis['duration']

match_analysis
# Out:
#      match_id     duration        xg  home_team_duration  max_posession
# 0     3890268  3105.198468  1.704714            0.493212            172
# 1     3890269  2586.192081  3.186915            0.586176            213
# 2     3890282  3051.304171  4.665310            0.499207            177
# 3     3890287  3287.595991  3.982188            0.824313            143
# 4     3890319  3672.900467  1.960017            0.694971            167
# ..        ...          ...       ...                 ...            ...
# 245   3890560  3317.339631  2.348650            0.326420            181
# 246   3890561  3559.617941  2.774578            0.446149            171
# 247   3890562  3492.866025  2.532932            0.839255            144
# 248   3890563  2748.193509  6.738388            0.431430            205
# 249   3890564  2976.259245  3.199977            0.501084            195
#
# [250 rows x 5 columns]

# %% [markdown]
# **df_duel**

# %%
selected_columns = [

    'id',
    'match_id',
    'location',
    'period',
    'possession',
    'possession_team',
    'under_pressure',
    'home_team',
    'home_team_flag',
    'foul_committed_card',
    'team',
    'x',
    'y',
    'counterpress',
    'index',
    'play_pattern'
]
# Check if the columns exist in the database
df_duel = new_dfs['df_duel']

existing_columns = [col for col in selected_columns if col in df_duel.columns]

# Create a new dataframe with only the existing selected columns
df_final_matches_selected_duel = df_duel[existing_columns]
df_final_matches_selected_duel
# Out:
#                                           id  match_id       location  period  \
# 3749    3c73cb65-1e7c-4f75-ae9d-9d58c17096da   3890561   [40.1, 28.0]       1
# 3750    f86304b1-9544-4e98-858c-745112e13220   3890561   [40.5, 49.7]       1
# 3751    b99ea45b-bb32-4737-acdd-f0956f0c6404   3890561   [31.0, 25.5]       1
# 3752    aa044964-a84f-4dca-a086-bace1265ddf7   3890561     [9.1, 9.0]       1
# 3753    df845598-2464-439a-b672-1dc3c43bcbc1   3890561   [47.0, 53.7]       1
# ...                                      ...       ...            ...     ...
# 879290  db753ae2-a51f-42db-b717-a48eb8a9df06   3890319   [70.8, 63.1]       2
# 879291  d85955d8-fbbd-4fb9-9af4-cddac7c052ee   3890319   [81.7, 62.2]       2
# 879292  07d01043-f697-4bf2-a787-2e64d500fbe0   3890319   [91.2, 70.6]       2
# 879293  ab741c4c-c513-4342-8a58-0e06934bae14   3890319    [78.1, 9.7]       2
# 879294  e4f0972d-b2d2-41b7-afa7-1a7fa32b1761   3890319  [110.7, 35.5]       2
#
#         possession possession_team under_pressure   home_team  home_team_flag  \
# 3749             8      Schalke 04           True  Hoffenheim               0
# 3750            10      Schalke 04           True  Hoffenheim               0
# 3751            14      Hoffenheim           True  Hoffenheim               1
# 3752            14      Hoffenheim           True  Hoffenheim               1
# 3753            17      Schalke 04           True  Hoffenheim               0
# ...            ...             ...            ...         ...             ...
# 879290         160     Hannover 96           True   Wolfsburg               0
# 879291         162     Hannover 96           True   Wolfsburg               0
# 879292         162     Hannover 96           True   Wolfsburg               0
# 879293         164     Hannover 96           True   Wolfsburg               0
# 879294         165     Hannover 96           True   Wolfsburg               0
#
#        foul_committed_card         team      x     y counterpress  index  \
# 3749                   NaN   Hoffenheim   40.1  28.0          NaN    277
# 3750                   NaN   Schalke 04   40.5  49.7         True    324
# 3751                   NaN   Hoffenheim   31.0  25.5         True    376
# 3752                   NaN   Schalke 04    9.1   9.0          NaN    390
# 3753                   NaN   Hoffenheim   47.0  53.7          NaN    435
# ...                    ...          ...    ...   ...          ...    ...
# 879290                 NaN    Wolfsburg   70.8  63.1          NaN   3742
# 879291                 NaN  Hannover 96   81.7  62.2          NaN   3799
# 879292                 NaN  Hannover 96   91.2  70.6          NaN   3806
# 879293                 NaN  Hannover 96   78.1   9.7          NaN   3840
# 879294                 NaN  Hannover 96  110.7  35.5          NaN   3860
#
#           play_pattern
# 3749    From Goal Kick
# 3750      Regular Play
# 3751      Regular Play
# 3752      Regular Play
# 3753    From Goal Kick
# ...                ...
# 879290     From Keeper
# 879291  From Goal Kick
# 879292  From Goal Kick
# 879293  From Goal Kick
# 879294  From Free Kick
#
# [21173 rows x 16 columns]

# %%
# Join df_final_matches_selected_foul_committed and df_final_matches on 'match_id' and 'possession'
df_merged = pd.merge(df_final_matches_selected_duel[['match_id', 'possession']],
                     df_final_matches[['match_id', 'possession', 'index']],
                     on=['match_id', 'possession'],
                     how='inner')

# Find the minimum index for each match_id and possession combination
df_min_index = df_merged.groupby(['match_id', 'possession'])['index'].min().reset_index()
df_min_index.rename(columns={'index': 'min_index'}, inplace=True)

# Join the minimum index back onto df_final_matches_selected_foul_committed
df_final_matches_selected_duel = pd.merge(df_final_matches_selected_duel,
                                          df_min_index,
                                          on=['match_id', 'possession'],
                                          how='left')

df_final_matches_selected_duel
# Out:
#                                          id  match_id       location  period  \
# 0      3c73cb65-1e7c-4f75-ae9d-9d58c17096da   3890561   [40.1, 28.0]       1
# 1      f86304b1-9544-4e98-858c-745112e13220   3890561   [40.5, 49.7]       1
# 2      b99ea45b-bb32-4737-acdd-f0956f0c6404   3890561   [31.0, 25.5]       1
# 3      aa044964-a84f-4dca-a086-bace1265ddf7   3890561     [9.1, 9.0]       1
# 4      df845598-2464-439a-b672-1dc3c43bcbc1   3890561   [47.0, 53.7]       1
# ...                                     ...       ...            ...     ...
# 21168  db753ae2-a51f-42db-b717-a48eb8a9df06   3890319   [70.8, 63.1]       2
# 21169  d85955d8-fbbd-4fb9-9af4-cddac7c052ee   3890319   [81.7, 62.2]       2
# 21170  07d01043-f697-4bf2-a787-2e64d500fbe0   3890319   [91.2, 70.6]       2
# 21171  ab741c4c-c513-4342-8a58-0e06934bae14   3890319    [78.1, 9.7]       2
# 21172  e4f0972d-b2d2-41b7-afa7-1a7fa32b1761   3890319  [110.7, 35.5]       2
#
#        possession possession_team under_pressure   home_team  home_team_flag  \
# 0               8      Schalke 04           True  Hoffenheim               0
# 1              10      Schalke 04           True  Hoffenheim               0
# 2              14      Hoffenheim           True  Hoffenheim               1
# 3              14      Hoffenheim           True  Hoffenheim               1
# 4              17      Schalke 04           True  Hoffenheim               0
# ...           ...             ...            ...         ...             ...
# 21168         160     Hannover 96           True   Wolfsburg               0
# 21169         162     Hannover 96           True   Wolfsburg               0
# 21170         162     Hannover 96           True   Wolfsburg               0
# 21171         164     Hannover 96           True   Wolfsburg               0
# 21172         165     Hannover 96           True   Wolfsburg               0
#
#       foul_committed_card         team      x     y counterpress  index  \
# 0                     NaN   Hoffenheim   40.1  28.0          NaN    277
# 1                     NaN   Schalke 04   40.5  49.7         True    324
# 2                     NaN   Hoffenheim   31.0  25.5         True    376
# 3                     NaN   Schalke 04    9.1   9.0          NaN    390
# 4                     NaN   Hoffenheim   47.0  53.7          NaN    435
# ...                   ...          ...    ...   ...          ...    ...
# 21168                 NaN    Wolfsburg   70.8  63.1          NaN   3742
# 21169                 NaN  Hannover 96   81.7  62.2          NaN   3799
# 21170                 NaN  Hannover 96   91.2  70.6          NaN   3806
# 21171                 NaN  Hannover 96   78.1   9.7          NaN   3840
# 21172                 NaN  Hannover 96  110.7  35.5          NaN   3860
#
#          play_pattern  min_index
# 0      From Goal Kick        265
# 1        Regular Play        300
# 2        Regular Play        376
# 3        Regular Play        376
# 4      From Goal Kick        414
# ...               ...        ...
# 21168     From Keeper       3711
# 21169  From Goal Kick       3797
# 21170  From Goal Kick       3797
# 21171  From Goal Kick       3838
# 21172  From Free Kick       3858
#
# [21173 rows x 17 columns]

# %%
df_final_matches_selected_duel = df_final_matches_selected_duel.sort_values(by=['match_id', 'possession', 'index'])
df_final_matches_selected_duel['sequence length'] = df_final_matches_selected_duel['index'] - df_final_matches_selected_duel['min_index']

# Initialize a list to store the counts for each shot
pass_counts = []

# Iterate through each row in df_final_matches_selected_foul_committed
for index, row in df_final_matches_selected_duel.iterrows():
    match_id = row['match_id']
    shot_index = row['index']
    min_index = row['min_index']

    # Filter df_final_matches for the current match_id and the relevant index range
    relevant_events = df_final_matches[
        (df_final_matches['match_id'] == match_id) &
        (df_final_matches['index'] >= min_index) &
        (df_final_matches['index'] <= shot_index)
    ]

    # Count the number of rows where 'type' is 'Pass' in the filtered events
    count_passes = relevant_events[relevant_events['type'] == 'Pass'].shape[0]

    # Append the count to the list
    pass_counts.append(count_passes)

# Add the pass counts as a new column to df_final_matches_selected_foul_committed
df_final_matches_selected_duel['passes_in_sequence'] = pass_counts

print(df_final_matches_selected_duel[['match_id', 'index', 'min_index', 'passes_in_sequence']].head())
print("\nFirst few rows of df_final_matches_selected_dispossessed with 'passes_in_sequence' column:")

df_final_matches_selected_duel = pd.merge(df_final_matches_selected_duel,
                                          df_selected_cols[['match_id', 'competition', 'season']],
                                          on='match_id',
                                          how='left')
print(df_final_matches_selected_duel.head())
df_final_matches_selected_duel['field'] = "Duel"
# Out:
#      match_id  index  min_index  passes_in_sequence
# 933   3890268     96         47                  16
# 934   3890268    164        103                  21
# 935   3890268    165        103                  21
# 936   3890268    187        103                  28
# 937   3890268    191        103                  30
#
# First few rows of df_final_matches_selected_dispossessed with 'passes_in_sequence' column:
#                                      id  match_id      location  period  \
# 0  a7fa7dea-ca81-4c64-a4ea-10aa8ce3e195   3890268  [53.0, 41.1]       1
# 1  d098b93c-c2f7-42c9-a01a-9160a176ab03   3890268  [63.7, 27.8]       1
# 2  bbc7293c-ea45-46e9-b676-971e2c2a8ff5   3890268  [62.2, 51.8]       1
# 3  f2b02261-48d8-48ec-bc77-afdb55480215   3890268  [56.7, 21.5]       1
# 4  1e13799d-a7c8-47d0-bad7-ce9e5206b8f4   3890268  [40.4, 11.1]       1
#
#    possession possession_team under_pressure      home_team  home_team_flag  \
# 0           3   Werder Bremen           True  Hertha Berlin               0
# 1           4   Hertha Berlin           True  Hertha Berlin               1
# 2           4   Hertha Berlin           True  Hertha Berlin               1
# 3           4   Hertha Berlin           True  Hertha Berlin               1
# 4           4   Hertha Berlin           True  Hertha Berlin               1
#
#   foul_committed_card  ...     x     y  counterpress index    play_pattern  \
# 0                 NaN  ...  53.0  41.1           NaN    96    Regular Play
# 1                 NaN  ...  63.7  27.8           NaN   164  From Free Kick
# 2                 NaN  ...  62.2  51.8          True   165  From Free Kick
# 3                 NaN  ...  56.7  21.5           NaN   187  From Free Kick
# 4                 NaN  ...  40.4  11.1           NaN   191  From Free Kick
#
#   min_index  sequence length  passes_in_sequence              competition  \
# 0        47               49                  16  Germany - 1. Bundesliga
# 1       103               61                  21  Germany - 1. Bundesliga
# 2       103               62                  21  Germany - 1. Bundesliga
# 3       103               84                  28  Germany - 1. Bundesliga
# 4       103               88                  30  Germany - 1. Bundesliga
#
#       season
# 0  2015/2016
# 1  2015/2016
# 2  2015/2016
# 3  2015/2016
# 4  2015/2016
#
# [5 rows x 21 columns]

# %% [markdown]
# **50/50**

# %%
selected_columns = [

    'id',
    'match_id',
    'location',
    'period',
    'possession',
    'possession_team',
    'under_pressure',
    'home_team',
    'home_team_flag',
    'foul_committed_card',
    'team',
    'x',
    'y',
    'counterpress',
    'index',
    'play_pattern'
]
# Check if the columns exist in the database
df_50 = new_dfs['df_50/50']

existing_columns = [col for col in selected_columns if col in df_duel.columns]

# Create a new dataframe with only the existing selected columns
df_50 = df_50[existing_columns]
df_50
# Out:
#                                           id  match_id      location  period  \
# 7447    ca2faf73-a331-4f22-a016-3c09d777b4d8   3890505  [66.7, 56.5]       1
# 10876   7481e322-cad4-4422-9df6-599e7fd14861   3890511   [64.9, 9.4]       1
# 10877   68e09fba-8321-40ba-89f9-3ee81aaee642   3890511  [55.2, 70.7]       1
# 10878   8320e3a9-c85d-4dda-a909-f31b0ae1d658   3890511   [53.1, 4.0]       2
# 10879   7b7718c8-379e-4495-9b44-86284818fa2a   3890511  [67.0, 76.1]       2
# ...                                      ...       ...           ...     ...
# 879700  64f1f539-2f09-4181-8d99-d1be4ad18a3f   3890319  [97.7, 40.6]       2
# 879701  47066f6d-c17d-4c4b-8485-ee3ffed93ddf   3890319  [95.0, 59.6]       2
# 879702  b190bb3c-c97d-4584-9170-87bb5a777238   3890319  [25.1, 20.5]       2
# 879703  2342e97f-9495-469f-ad77-5923755eff3f   3890319  [35.2, 26.8]       2
# 879704  b35562a1-54a0-44ce-a12d-da45debf2cf8   3890319  [84.9, 53.3]       2
#
#         possession possession_team under_pressure      home_team  \
# 7447            26   Bayern Munich           True  Bayern Munich
# 10876           21   Hertha Berlin           True  Hertha Berlin
# 10877           21   Hertha Berlin           True  Hertha Berlin
# 10878          181   Hertha Berlin           True  Hertha Berlin
# 10879          181   Hertha Berlin           True  Hertha Berlin
# ...            ...             ...            ...            ...
# 879700          84       Wolfsburg           True      Wolfsburg
# 879701         106       Wolfsburg           True      Wolfsburg
# 879702         106       Wolfsburg           True      Wolfsburg
# 879703         106       Wolfsburg           True      Wolfsburg
# 879704         106       Wolfsburg           True      Wolfsburg
#
#         home_team_flag foul_committed_card                 team     x     y  \
# 7447                 1                 NaN  Eintracht Frankfurt  66.7  56.5
# 10876                1                 NaN          Hannover 96  64.9   9.4
# 10877                1                 NaN        Hertha Berlin  55.2  70.7
# 10878                1                 NaN        Hertha Berlin  53.1   4.0
# 10879                1                 NaN          Hannover 96  67.0  76.1
# ...                ...                 ...                  ...   ...   ...
# 879700               1                 NaN            Wolfsburg  97.7  40.6
# 879701               1                 NaN            Wolfsburg  95.0  59.6
# 879702               1                 NaN          Hannover 96  25.1  20.5
# 879703               1                 NaN          Hannover 96  35.2  26.8
# 879704               1                 NaN            Wolfsburg  84.9  53.3
#
#        counterpress  index   play_pattern
# 7447            NaN    475   Regular Play
# 10876           NaN    497   Regular Play
# 10877           NaN    498   Regular Play
# 10878           NaN   3372   Regular Play
# 10879           NaN   3373   Regular Play
# ...             ...    ...            ...
# 879700          NaN   2114  From Kick Off
# 879701          NaN   2730   Regular Play
# 879702          NaN   2731   Regular Play
# 879703          NaN   2732   Regular Play
# 879704          NaN   2733   Regular Play
#
# [1235 rows x 16 columns]

# %%
df_merged = pd.merge(df_50[['match_id', 'possession']],
                     df_final_matches[['match_id', 'possession', 'index']],
                     on=['match_id', 'possession'],
                     how='inner')

# Find the minimum index for each match_id and possession combination
df_min_index = df_merged.groupby(['match_id', 'possession'])['index'].min().reset_index()
df_min_index.rename(columns={'index': 'min_index'}, inplace=True)

# Join the minimum index back onto df_final_matches_selected_foul_committed
df_50 = pd.merge(df_50,
                                          df_min_index,
                                          on=['match_id', 'possession'],
                                          how='left')

df_50
# Out:
#                                         id  match_id      location  period  \
# 0     ca2faf73-a331-4f22-a016-3c09d777b4d8   3890505  [66.7, 56.5]       1
# 1     7481e322-cad4-4422-9df6-599e7fd14861   3890511   [64.9, 9.4]       1
# 2     68e09fba-8321-40ba-89f9-3ee81aaee642   3890511  [55.2, 70.7]       1
# 3     8320e3a9-c85d-4dda-a909-f31b0ae1d658   3890511   [53.1, 4.0]       2
# 4     7b7718c8-379e-4495-9b44-86284818fa2a   3890511  [67.0, 76.1]       2
# ...                                    ...       ...           ...     ...
# 1230  64f1f539-2f09-4181-8d99-d1be4ad18a3f   3890319  [97.7, 40.6]       2
# 1231  47066f6d-c17d-4c4b-8485-ee3ffed93ddf   3890319  [95.0, 59.6]       2
# 1232  b190bb3c-c97d-4584-9170-87bb5a777238   3890319  [25.1, 20.5]       2
# 1233  2342e97f-9495-469f-ad77-5923755eff3f   3890319  [35.2, 26.8]       2
# 1234  b35562a1-54a0-44ce-a12d-da45debf2cf8   3890319  [84.9, 53.3]       2
#
#       possession possession_team under_pressure      home_team  \
# 0             26   Bayern Munich           True  Bayern Munich
# 1             21   Hertha Berlin           True  Hertha Berlin
# 2             21   Hertha Berlin           True  Hertha Berlin
# 3            181   Hertha Berlin           True  Hertha Berlin
# 4            181   Hertha Berlin           True  Hertha Berlin
# ...          ...             ...            ...            ...
# 1230          84       Wolfsburg           True      Wolfsburg
# 1231         106       Wolfsburg           True      Wolfsburg
# 1232         106       Wolfsburg           True      Wolfsburg
# 1233         106       Wolfsburg           True      Wolfsburg
# 1234         106       Wolfsburg           True      Wolfsburg
#
#       home_team_flag foul_committed_card                 team     x     y  \
# 0                  1                 NaN  Eintracht Frankfurt  66.7  56.5
# 1                  1                 NaN          Hannover 96  64.9   9.4
# 2                  1                 NaN        Hertha Berlin  55.2  70.7
# 3                  1                 NaN        Hertha Berlin  53.1   4.0
# 4                  1                 NaN          Hannover 96  67.0  76.1
# ...              ...                 ...                  ...   ...   ...
# 1230               1                 NaN            Wolfsburg  97.7  40.6
# 1231               1                 NaN            Wolfsburg  95.0  59.6
# 1232               1                 NaN          Hannover 96  25.1  20.5
# 1233               1                 NaN          Hannover 96  35.2  26.8
# 1234               1                 NaN            Wolfsburg  84.9  53.3
#
#      counterpress  index   play_pattern  min_index
# 0             NaN    475   Regular Play        450
# 1             NaN    497   Regular Play        482
# 2             NaN    498   Regular Play        482
# 3             NaN   3372   Regular Play       3361
# 4             NaN   3373   Regular Play       3361
# ...           ...    ...            ...        ...
# 1230          NaN   2114  From Kick Off       1969
# 1231          NaN   2730   Regular Play       2707
# 1232          NaN   2731   Regular Play       2707
# 1233          NaN   2732   Regular Play       2707
# 1234          NaN   2733   Regular Play       2707
#
# [1235 rows x 17 columns]

# %%
df_50 = df_50.sort_values(by=['match_id', 'possession', 'index'])
df_50['sequence length'] = df_50['index'] - df_50['min_index']

# Initialize a list to store the counts for each shot
pass_counts = []

# Iterate through each row in df_final_matches_selected_foul_committed
for index, row in df_50.iterrows():
    match_id = row['match_id']
    shot_index = row['index']
    min_index = row['min_index']

    # Filter df_final_matches for the current match_id and the relevant index range
    relevant_events = df_final_matches[
        (df_final_matches['match_id'] == match_id) &
        (df_final_matches['index'] >= min_index) &
        (df_final_matches['index'] <= shot_index)
    ]

    # Count the number of rows where 'type' is 'Pass' in the filtered events
    count_passes = relevant_events[relevant_events['type'] == 'Pass'].shape[0]

    # Append the count to the list
    pass_counts.append(count_passes)

# Add the pass counts as a new column to df_final_matches_selected_foul_committed
df_50['passes_in_sequence'] = pass_counts

print(df_50[['match_id', 'index', 'min_index', 'passes_in_sequence']].head())
print("\nFirst few rows of df_final_matches_selected_dispossessed with 'passes_in_sequence' column:")

df_50 = pd.merge(df_50,
                                          df_selected_cols[['match_id', 'competition', 'season']],
                                          on='match_id',
                                          how='left')
print(df_50.head())
df_50['field'] = "50/50"
# Out:
#     match_id  index  min_index  passes_in_sequence
# 45   3890268    769        763                   1
# 46   3890268    770        763                   1
# 47   3890268   2025       2008                   4
# 48   3890268   2026       2008                   4
# 49   3890268   2215       2199                   6
#
# First few rows of df_final_matches_selected_dispossessed with 'passes_in_sequence' column:
#                                      id  match_id       location  period  \
# 0  7f0451a5-6844-45db-82f7-bbffd7b04942   3890268   [13.6, 50.5]       1
# 1  5aba3af9-c42b-4228-8a4b-147b6e62cc88   3890268  [106.5, 29.6]       1
# 2  00c1df75-ffba-490b-95aa-b7332105ab09   3890268   [85.7, 38.4]       2
# 3  63d510e1-6e0c-48d6-93c5-70b468275345   3890268   [34.4, 41.7]       2
# 4  ac76b486-f617-426f-ad73-2f0119166469   3890268   [70.0, 50.6]       2
#
#    possession possession_team under_pressure      home_team  home_team_flag  \
# 0          44   Werder Bremen           True  Hertha Berlin               0
# 1          44   Werder Bremen           True  Hertha Berlin               0
# 2         102   Hertha Berlin           True  Hertha Berlin               1
# 3         102   Hertha Berlin           True  Hertha Berlin               1
# 4         112   Werder Bremen           True  Hertha Berlin               0
#
#   foul_committed_card  ...      x     y  counterpress index    play_pattern  \
# 0                 NaN  ...   13.6  50.5           NaN   769  From Free Kick
# 1                 NaN  ...  106.5  29.6           NaN   770  From Free Kick
# 2                 NaN  ...   85.7  38.4           NaN  2025  From Free Kick
# 3                 NaN  ...   34.4  41.7           NaN  2026  From Free Kick
# 4                 NaN  ...   70.0  50.6           NaN  2215  From Free Kick
#
#   min_index  sequence length  passes_in_sequence              competition  \
# 0       763                6                   1  Germany - 1. Bundesliga
# 1       763                7                   1  Germany - 1. Bundesliga
# 2      2008               17                   4  Germany - 1. Bundesliga
# 3      2008               18                   4  Germany - 1. Bundesliga
# 4      2199               16                   6  Germany - 1. Bundesliga
#
#       season
# 0  2015/2016
# 1  2015/2016
# 2  2015/2016
# 3  2015/2016
# 4  2015/2016
#
# [5 rows x 21 columns]

# %% [markdown]
# **df_dispossessed** - reviewed

# %%
selected_columns = [
    'id',
    'match_id',
    'location',
    'period',
    'possession',
    'possession_team',
    'under_pressure',
    'home_team',
    'home_team_flag',
    'foul_committed_card',
    'team',
    'x',
    'y',
    'counterpress',
    'index',
    'play_pattern'
]
# Check if the columns exist in the database
df_dispossessed = new_dfs['df_dispossessed']

existing_columns = [col for col in selected_columns if col in df_dispossessed.columns]

# Create a new dataframe with only the existing selected columns
df_final_matches_selected_dispossessed = df_dispossessed[existing_columns]
df_final_matches_selected_dispossessed
# Out:
#                                           id  match_id       location  period  \
# 3893    b87722f9-5324-498e-8525-4cb4040653f0   3890561   [69.9, 23.1]       1
# 3894    03dc0915-4ceb-4ab6-be47-ea9e4c37c2ca   3890561   [62.6, 49.9]       1
# 3895    562ee383-2ba3-479d-8a25-1f64e1165519   3890561  [115.7, 13.4]       1
# 3896    87251742-2fa2-4cc5-baf3-270402d56562   3890561    [4.8, 74.5]       1
# 3897    35d5f1e6-2918-4f39-9aec-d79177c779b6   3890561  [108.6, 46.1]       1
# ...                                      ...       ...            ...     ...
# 879599  a1977316-ba12-43cf-a835-7d487e3d3f38   3890319   [83.1, 76.4]       2
# 879600  e2ee46a9-70fd-43eb-b9b7-968cd5d1c22a   3890319   [89.0, 74.8]       2
# 879601  bd37b89b-ad0a-4917-8a8c-b0f1c3047ad6   3890319    [76.5, 5.3]       2
# 879602  dc97cc22-ae79-4428-80e4-26ec3f8398cd   3890319    [50.2, 5.6]       2
# 879603  2730d467-8edd-4fc5-b5a3-b7e478aafa57   3890319   [49.3, 17.0]       2
#
#         possession possession_team under_pressure   home_team  home_team_flag  \
# 3893            23      Hoffenheim           True  Hoffenheim               1
# 3894            33      Schalke 04           True  Hoffenheim               0
# 3895            36      Hoffenheim           True  Hoffenheim               1
# 3896            37      Schalke 04           True  Hoffenheim               0
# 3897            39      Hoffenheim           True  Hoffenheim               1
# ...            ...             ...            ...         ...             ...
# 879599         132       Wolfsburg           True   Wolfsburg               1
# 879600         136       Wolfsburg           True   Wolfsburg               1
# 879601         148     Hannover 96           True   Wolfsburg               0
# 879602         159     Hannover 96           True   Wolfsburg               0
# 879603         160     Hannover 96           True   Wolfsburg               0
#
#        foul_committed_card         team      x     y counterpress  index  \
# 3893                   NaN   Schalke 04   69.9  23.1          NaN    564
# 3894                   NaN   Schalke 04   62.6  49.9          NaN    719
# 3895                   NaN   Hoffenheim  115.7  13.4          NaN    832
# 3896                   NaN   Schalke 04    4.8  74.5          NaN    837
# 3897                   NaN   Hoffenheim  108.6  46.1          NaN    887
# ...                    ...          ...    ...   ...          ...    ...
# 879599                 NaN    Wolfsburg   83.1  76.4          NaN   3182
# 879600                 NaN    Wolfsburg   89.0  74.8          NaN   3328
# 879601                 NaN  Hannover 96   76.5   5.3          NaN   3537
# 879602                 NaN  Hannover 96   50.2   5.6          NaN   3705
# 879603                 NaN  Hannover 96   49.3  17.0          NaN   3741
#
#           play_pattern
# 3893    From Free Kick
# 3894      Regular Play
# 3895    From Free Kick
# 3896      Regular Play
# 3897      Regular Play
# ...                ...
# 879599    Regular Play
# 879600    Regular Play
# 879601  From Goal Kick
# 879602   From Throw In
# 879603     From Keeper
#
# [6302 rows x 16 columns]

# %%
# Join df_final_matches_selected_foul_committed and df_final_matches on 'match_id' and 'possession'
df_merged = pd.merge(df_final_matches_selected_dispossessed[['match_id', 'possession']],
                     df_final_matches[['match_id', 'possession', 'index']],
                     on=['match_id', 'possession'],
                     how='inner')

# Find the minimum index for each match_id and possession combination
df_min_index = df_merged.groupby(['match_id', 'possession'])['index'].min().reset_index()
df_min_index.rename(columns={'index': 'min_index'}, inplace=True)

# Join the minimum index back onto df_final_matches_selected_foul_committed
df_final_matches_selected_dispossessed = pd.merge(df_final_matches_selected_dispossessed,
                                          df_min_index,
                                          on=['match_id', 'possession'],
                                          how='left')

df_final_matches_selected_dispossessed
# Out:
#                                         id  match_id       location  period  \
# 0     b87722f9-5324-498e-8525-4cb4040653f0   3890561   [69.9, 23.1]       1
# 1     03dc0915-4ceb-4ab6-be47-ea9e4c37c2ca   3890561   [62.6, 49.9]       1
# 2     562ee383-2ba3-479d-8a25-1f64e1165519   3890561  [115.7, 13.4]       1
# 3     87251742-2fa2-4cc5-baf3-270402d56562   3890561    [4.8, 74.5]       1
# 4     35d5f1e6-2918-4f39-9aec-d79177c779b6   3890561  [108.6, 46.1]       1
# ...                                    ...       ...            ...     ...
# 6297  a1977316-ba12-43cf-a835-7d487e3d3f38   3890319   [83.1, 76.4]       2
# 6298  e2ee46a9-70fd-43eb-b9b7-968cd5d1c22a   3890319   [89.0, 74.8]       2
# 6299  bd37b89b-ad0a-4917-8a8c-b0f1c3047ad6   3890319    [76.5, 5.3]       2
# 6300  dc97cc22-ae79-4428-80e4-26ec3f8398cd   3890319    [50.2, 5.6]       2
# 6301  2730d467-8edd-4fc5-b5a3-b7e478aafa57   3890319   [49.3, 17.0]       2
#
#       possession possession_team under_pressure   home_team  home_team_flag  \
# 0             23      Hoffenheim           True  Hoffenheim               1
# 1             33      Schalke 04           True  Hoffenheim               0
# 2             36      Hoffenheim           True  Hoffenheim               1
# 3             37      Schalke 04           True  Hoffenheim               0
# 4             39      Hoffenheim           True  Hoffenheim               1
# ...          ...             ...            ...         ...             ...
# 6297         132       Wolfsburg           True   Wolfsburg               1
# 6298         136       Wolfsburg           True   Wolfsburg               1
# 6299         148     Hannover 96           True   Wolfsburg               0
# 6300         159     Hannover 96           True   Wolfsburg               0
# 6301         160     Hannover 96           True   Wolfsburg               0
#
#      foul_committed_card         team      x     y counterpress  index  \
# 0                    NaN   Schalke 04   69.9  23.1          NaN    564
# 1                    NaN   Schalke 04   62.6  49.9          NaN    719
# 2                    NaN   Hoffenheim  115.7  13.4          NaN    832
# 3                    NaN   Schalke 04    4.8  74.5          NaN    837
# 4                    NaN   Hoffenheim  108.6  46.1          NaN    887
# ...                  ...          ...    ...   ...          ...    ...
# 6297                 NaN    Wolfsburg   83.1  76.4          NaN   3182
# 6298                 NaN    Wolfsburg   89.0  74.8          NaN   3328
# 6299                 NaN  Hannover 96   76.5   5.3          NaN   3537
# 6300                 NaN  Hannover 96   50.2   5.6          NaN   3705
# 6301                 NaN  Hannover 96   49.3  17.0          NaN   3741
#
#         play_pattern  min_index
# 0     From Free Kick        560
# 1       Regular Play        689
# 2     From Free Kick        810
# 3       Regular Play        833
# 4       Regular Play        859
# ...              ...        ...
# 6297    Regular Play       3161
# 6298    Regular Play       3292
# 6299  From Goal Kick       3530
# 6300   From Throw In       3701
# 6301     From Keeper       3711
#
# [6302 rows x 17 columns]

# %%
df_final_matches_selected_dispossessed = df_final_matches_selected_dispossessed.sort_values(by=['match_id', 'possession', 'index'])
df_final_matches_selected_dispossessed['sequence length'] = df_final_matches_selected_dispossessed['index'] - df_final_matches_selected_dispossessed['min_index']

# Initialize a list to store the counts for each shot
pass_counts = []

# Iterate through each row in df_final_matches_selected_foul_committed
for index, row in df_final_matches_selected_dispossessed.iterrows():
    match_id = row['match_id']
    shot_index = row['index']
    min_index = row['min_index']

    # Filter df_final_matches for the current match_id and the relevant index range
    relevant_events = df_final_matches[
        (df_final_matches['match_id'] == match_id) &
        (df_final_matches['index'] >= min_index) &
        (df_final_matches['index'] <= shot_index)
    ]

    # Count the number of rows where 'type' is 'Pass' in the filtered events
    count_passes = relevant_events[relevant_events['type'] == 'Pass'].shape[0]

    # Append the count to the list
    pass_counts.append(count_passes)

# Add the pass counts as a new column to df_final_matches_selected_foul_committed
df_final_matches_selected_dispossessed['passes_in_sequence'] = pass_counts

print(df_final_matches_selected_dispossessed[['match_id', 'index', 'min_index', 'passes_in_sequence']].head())
print("\nFirst few rows of df_final_matches_selected_dispossessed with 'passes_in_sequence' column:")

df_final_matches_selected_dispossessed = pd.merge(df_final_matches_selected_dispossessed,
                                          df_selected_cols[['match_id', 'competition', 'season']],
                                          on='match_id',
                                          how='left')
print(df_final_matches_selected_dispossessed.head())
df_final_matches_selected_dispossessed['field'] = "Dispossessed"
# Out:
#      match_id  index  min_index  passes_in_sequence
# 279   3890268    163        103                  21
# 280   3890268    203        195                   1
# 281   3890268    243        238                   1
# 282   3890268    399        377                   7
# 283   3890268    540        512                   8
#
# First few rows of df_final_matches_selected_dispossessed with 'passes_in_sequence' column:
#                                      id  match_id       location  period  \
# 0  a9d9561d-7d27-48d0-bed8-5cf0d6a06c83   3890268   [56.4, 52.3]       1
# 1  d6da819e-021b-4686-9c90-fa9b3debb0b5   3890268  [112.5, 56.9]       1
# 2  6edf750a-11f3-4768-be71-82d435b1f7fc   3890268   [79.5, 78.3]       1
# 3  f17cb533-7746-4f1a-ae50-d169b42b0582   3890268   [69.2, 73.0]       1
# 4  055af85d-d813-478d-8996-0fdaa1646adc   3890268   [53.9, 31.4]       1
#
#    possession possession_team under_pressure      home_team  home_team_flag  \
# 0           4   Hertha Berlin           True  Hertha Berlin               1
# 1           5   Hertha Berlin           True  Hertha Berlin               1
# 2           9   Werder Bremen           True  Hertha Berlin               0
# 3          18   Hertha Berlin           True  Hertha Berlin               1
# 4          25   Hertha Berlin           True  Hertha Berlin               1
#
#   foul_committed_card  ...      x     y  counterpress index    play_pattern  \
# 0                 NaN  ...   56.4  52.3           NaN   163  From Free Kick
# 1                 NaN  ...  112.5  56.9           NaN   203   From Throw In
# 2                 NaN  ...   79.5  78.3           NaN   243   From Throw In
# 3                 NaN  ...   69.2  73.0           NaN   399   From Throw In
# 4                 NaN  ...   53.9  31.4           NaN   540  From Free Kick
#
#   min_index  sequence length  passes_in_sequence              competition  \
# 0       103               60                  21  Germany - 1. Bundesliga
# 1       195                8                   1  Germany - 1. Bundesliga
# 2       238                5                   1  Germany - 1. Bundesliga
# 3       377               22                   7  Germany - 1. Bundesliga
# 4       512               28                   8  Germany - 1. Bundesliga
#
#       season
# 0  2015/2016
# 1  2015/2016
# 2  2015/2016
# 3  2015/2016
# 4  2015/2016
#
# [5 rows x 21 columns]

# %%
df_final_matches_selected_dispossessed
# Out:
#                                         id  match_id       location  period  \
# 0     a9d9561d-7d27-48d0-bed8-5cf0d6a06c83   3890268   [56.4, 52.3]       1
# 1     d6da819e-021b-4686-9c90-fa9b3debb0b5   3890268  [112.5, 56.9]       1
# 2     6edf750a-11f3-4768-be71-82d435b1f7fc   3890268   [79.5, 78.3]       1
# 3     f17cb533-7746-4f1a-ae50-d169b42b0582   3890268   [69.2, 73.0]       1
# 4     055af85d-d813-478d-8996-0fdaa1646adc   3890268   [53.9, 31.4]       1
# ...                                    ...       ...            ...     ...
# 6297  ea13bf08-91fb-4bd8-8ef1-c6e620ef6271   3890564   [77.1, 19.9]       2
# 6298  ad43fcd3-dfec-4309-bc81-078b783de09a   3890564  [105.3, 62.7]       2
# 6299  f926d744-d517-4cfb-922c-014d22262b9d   3890564    [19.9, 7.5]       2
# 6300  3dbf0855-8d17-4a16-872d-6e48e8d6d3e2   3890564  [115.1, 12.5]       2
# 6301  2ebed5f5-1928-4ba0-b876-6e7e30847774   3890564    [49.7, 4.0]       2
#
#       possession possession_team under_pressure      home_team  \
# 0              4   Hertha Berlin           True  Hertha Berlin
# 1              5   Hertha Berlin           True  Hertha Berlin
# 2              9   Werder Bremen           True  Hertha Berlin
# 3             18   Hertha Berlin           True  Hertha Berlin
# 4             25   Hertha Berlin           True  Hertha Berlin
# ...          ...             ...            ...            ...
# 6297         166    Hamburger SV           True       Augsburg
# 6298         168    Hamburger SV           True       Augsburg
# 6299         169    Hamburger SV           True       Augsburg
# 6300         169    Hamburger SV           True       Augsburg
# 6301         185    Hamburger SV           True       Augsburg
#
#       home_team_flag foul_committed_card  ...     y  counterpress  index  \
# 0                  1                 NaN  ...  52.3           NaN    163
# 1                  1                 NaN  ...  56.9           NaN    203
# 2                  0                 NaN  ...  78.3           NaN    243
# 3                  1                 NaN  ...  73.0           NaN    399
# 4                  1                 NaN  ...  31.4           NaN    540
# ...              ...                 ...  ...   ...           ...    ...
# 6297               0                 NaN  ...  19.9           NaN   2882
# 6298               0                 NaN  ...  62.7           NaN   2980
# 6299               0                 NaN  ...   7.5           NaN   2992
# 6300               0                 NaN  ...  12.5           NaN   3009
# 6301               0                 NaN  ...   4.0           NaN   3182
#
#         play_pattern  min_index sequence length  passes_in_sequence  \
# 0     From Free Kick        103              60                  21
# 1      From Throw In        195               8                   1
# 2      From Throw In        238               5                   1
# 3      From Throw In        377              22                   7
# 4     From Free Kick        512              28                   8
# ...              ...        ...             ...                 ...
# 6297  From Free Kick       2877               5                   1
# 6298    Regular Play       2899              81                  22
# 6299   From Throw In       2983               9                   1
# 6300   From Throw In       2983              26                   4
# 6301   From Throw In       3170              12                   2
#
#                   competition     season         field
# 0     Germany - 1. Bundesliga  2015/2016  Dispossessed
# 1     Germany - 1. Bundesliga  2015/2016  Dispossessed
# 2     Germany - 1. Bundesliga  2015/2016  Dispossessed
# 3     Germany - 1. Bundesliga  2015/2016  Dispossessed
# 4     Germany - 1. Bundesliga  2015/2016  Dispossessed
# ...                       ...        ...           ...
# 6297  Germany - 1. Bundesliga  2015/2016  Dispossessed
# 6298  Germany - 1. Bundesliga  2015/2016  Dispossessed
# 6299  Germany - 1. Bundesliga  2015/2016  Dispossessed
# 6300  Germany - 1. Bundesliga  2015/2016  Dispossessed
# 6301  Germany - 1. Bundesliga  2015/2016  Dispossessed
#
# [6302 rows x 22 columns]

# %% [markdown]
# **Foul Committed**

# %%
selected_columns = [
    'id',
    'match_id',
    'location',
    'period',
    'possession',
    'possession_team',
    'under_pressure',
    'home_team',
    'home_team_flag',
    'foul_committed_card',
    'team',
    'x',
    'y',
    'counterpress',
    'index',
    'play_pattern',


]
# Check if the columns exist in the database
df_foul_committed = new_dfs['df_foul_committed']

existing_columns = [col for col in selected_columns if col in df_foul_committed.columns]

# Create a new dataframe with only the existing selected columns
df_final_matches_selected_foul_committed = df_foul_committed[existing_columns]
df_final_matches_selected_foul_committed
# Out:
#                                           id  match_id       location  period  \
# 3632    f1dd3418-5813-4df3-b319-97e1f821a4bb   3890561   [52.0, 55.2]       1
# 3633    e0b0ab13-9eed-4a18-aadb-c73c194c6f6a   3890561   [91.3, 76.3]       1
# 3634    bd08408b-0d22-40b0-a6ce-38bff67eacc5   3890561  [105.4, 70.7]       1
# 3635    4487ead1-4686-4618-8781-30dbabbf6a0a   3890561  [114.8, 21.4]       1
# 3636    0f56d472-b60a-4ced-b3c7-eb261eed470b   3890561   [87.1, 30.8]       1
# ...                                      ...       ...            ...     ...
# 879621  bec69705-458f-4fad-b0f2-ce1b1ecf60fa   3890319   [58.6, 12.1]       2
# 879622  0f57793c-4d5e-4ed0-ae23-4df87ea36a01   3890319   [40.3, 37.6]       2
# 879623  72f82593-ba2c-46a5-8c12-de9b95c7fb92   3890319   [55.1, 73.4]       2
# 879624  29bac64e-733f-4865-9fa4-c3a5bf62c5db   3890319   [38.7, 25.4]       2
# 879625  169277ed-cecf-48f9-b473-16b48a5f7c4f   3890319    [34.9, 5.0]       2
#
#         possession possession_team under_pressure   home_team  home_team_flag  \
# 3632             7      Hoffenheim            NaN  Hoffenheim               1
# 3633            19      Schalke 04            NaN  Hoffenheim               0
# 3634            20      Schalke 04            NaN  Hoffenheim               0
# 3635            22      Schalke 04            NaN  Hoffenheim               0
# 3636            25      Hoffenheim            NaN  Hoffenheim               1
# ...            ...             ...            ...         ...             ...
# 879621         129       Wolfsburg            NaN   Wolfsburg               1
# 879622         146       Wolfsburg            NaN   Wolfsburg               1
# 879623         155     Hannover 96            NaN   Wolfsburg               0
# 879624         164     Hannover 96            NaN   Wolfsburg               0
# 879625         166       Wolfsburg            NaN   Wolfsburg               1
#
#        foul_committed_card         team      x     y counterpress  index  \
# 3632                   NaN   Schalke 04   52.0  55.2          NaN    200
# 3633                   NaN   Hoffenheim   91.3  76.3         True    477
# 3634                   NaN   Schalke 04  105.4  70.7          NaN    498
# 3635                   NaN   Schalke 04  114.8  21.4         True    558
# 3636                   NaN   Schalke 04   87.1  30.8         True    601
# ...                    ...          ...    ...   ...          ...    ...
# 879621                 NaN  Hannover 96   58.6  12.1          NaN   3116
# 879622         Yellow Card  Hannover 96   40.3  37.6          NaN   3506
# 879623                 NaN    Wolfsburg   55.1  73.4          NaN   3640
# 879624                 NaN    Wolfsburg   38.7  25.4          NaN   3856
# 879625         Yellow Card  Hannover 96   34.9   5.0          NaN   3873
#
#           play_pattern
# 3632      Regular Play
# 3633      Regular Play
# 3634    From Free Kick
# 3635    From Goal Kick
# 3636      Regular Play
# ...                ...
# 879621   From Throw In
# 879622   From Throw In
# 879623   From Throw In
# 879624  From Goal Kick
# 879625    Regular Play
#
# [8001 rows x 16 columns]

# %%
# Join df_final_matches_selected_foul_committed and df_final_matches on 'match_id' and 'possession'
df_merged = pd.merge(df_final_matches_selected_foul_committed[['match_id', 'possession']],
                     df_final_matches[['match_id', 'possession', 'index']],
                     on=['match_id', 'possession'],
                     how='inner')

# Find the minimum index for each match_id and possession combination
df_min_index = df_merged.groupby(['match_id', 'possession'])['index'].min().reset_index()
df_min_index.rename(columns={'index': 'min_index'}, inplace=True)

# Join the minimum index back onto df_final_matches_selected_foul_committed
df_final_matches_selected_foul_committed = pd.merge(df_final_matches_selected_foul_committed,
                                          df_min_index,
                                          on=['match_id', 'possession'],
                                          how='left')

df_final_matches_selected_foul_committed
# Out:
#                                         id  match_id       location  period  \
# 0     f1dd3418-5813-4df3-b319-97e1f821a4bb   3890561   [52.0, 55.2]       1
# 1     e0b0ab13-9eed-4a18-aadb-c73c194c6f6a   3890561   [91.3, 76.3]       1
# 2     bd08408b-0d22-40b0-a6ce-38bff67eacc5   3890561  [105.4, 70.7]       1
# 3     4487ead1-4686-4618-8781-30dbabbf6a0a   3890561  [114.8, 21.4]       1
# 4     0f56d472-b60a-4ced-b3c7-eb261eed470b   3890561   [87.1, 30.8]       1
# ...                                    ...       ...            ...     ...
# 7996  bec69705-458f-4fad-b0f2-ce1b1ecf60fa   3890319   [58.6, 12.1]       2
# 7997  0f57793c-4d5e-4ed0-ae23-4df87ea36a01   3890319   [40.3, 37.6]       2
# 7998  72f82593-ba2c-46a5-8c12-de9b95c7fb92   3890319   [55.1, 73.4]       2
# 7999  29bac64e-733f-4865-9fa4-c3a5bf62c5db   3890319   [38.7, 25.4]       2
# 8000  169277ed-cecf-48f9-b473-16b48a5f7c4f   3890319    [34.9, 5.0]       2
#
#       possession possession_team under_pressure   home_team  home_team_flag  \
# 0              7      Hoffenheim            NaN  Hoffenheim               1
# 1             19      Schalke 04            NaN  Hoffenheim               0
# 2             20      Schalke 04            NaN  Hoffenheim               0
# 3             22      Schalke 04            NaN  Hoffenheim               0
# 4             25      Hoffenheim            NaN  Hoffenheim               1
# ...          ...             ...            ...         ...             ...
# 7996         129       Wolfsburg            NaN   Wolfsburg               1
# 7997         146       Wolfsburg            NaN   Wolfsburg               1
# 7998         155     Hannover 96            NaN   Wolfsburg               0
# 7999         164     Hannover 96            NaN   Wolfsburg               0
# 8000         166       Wolfsburg            NaN   Wolfsburg               1
#
#      foul_committed_card         team      x     y counterpress  index  \
# 0                    NaN   Schalke 04   52.0  55.2          NaN    200
# 1                    NaN   Hoffenheim   91.3  76.3         True    477
# 2                    NaN   Schalke 04  105.4  70.7          NaN    498
# 3                    NaN   Schalke 04  114.8  21.4         True    558
# 4                    NaN   Schalke 04   87.1  30.8         True    601
# ...                  ...          ...    ...   ...          ...    ...
# 7996                 NaN  Hannover 96   58.6  12.1          NaN   3116
# 7997         Yellow Card  Hannover 96   40.3  37.6          NaN   3506
# 7998                 NaN    Wolfsburg   55.1  73.4          NaN   3640
# 7999                 NaN    Wolfsburg   38.7  25.4          NaN   3856
# 8000         Yellow Card  Hannover 96   34.9   5.0          NaN   3873
#
#         play_pattern  min_index
# 0       Regular Play        192
# 1       Regular Play        475
# 2     From Free Kick        479
# 3     From Goal Kick        519
# 4       Regular Play        599
# ...              ...        ...
# 7996   From Throw In       3109
# 7997   From Throw In       3495
# 7998   From Throw In       3629
# 7999  From Goal Kick       3838
# 8000    Regular Play       3862
#
# [8001 rows x 17 columns]

# %%
df_final_matches_selected_foul_committed = df_final_matches_selected_foul_committed.sort_values(by=['match_id', 'possession', 'index'])
df_final_matches_selected_foul_committed['sequence length'] = df_final_matches_selected_foul_committed['index'] - df_final_matches_selected_foul_committed['min_index']

# Initialize a list to store the counts for each shot
pass_counts = []

# Iterate through each row in df_final_matches_selected_foul_committed
for index, row in df_final_matches_selected_foul_committed.iterrows():
    match_id = row['match_id']
    shot_index = row['index']
    min_index = row['min_index']

    # Filter df_final_matches for the current match_id and the relevant index range
    relevant_events = df_final_matches[
        (df_final_matches['match_id'] == match_id) &
        (df_final_matches['index'] >= min_index) &
        (df_final_matches['index'] <= shot_index)
    ]

    # Count the number of rows where 'type' is 'Pass' in the filtered events
    count_passes = relevant_events[relevant_events['type'] == 'Pass'].shape[0]

    # Append the count to the list
    pass_counts.append(count_passes)

# Add the pass counts as a new column to df_final_matches_selected_foul_committed
df_final_matches_selected_foul_committed['passes_in_sequence'] = pass_counts

print(df_final_matches_selected_foul_committed[['match_id', 'index', 'min_index', 'passes_in_sequence']].head())
print("\nFirst few rows of df_final_matches_selected_foul_committed with 'passes_in_sequence' column:")

df_final_matches_selected_foul_committed = pd.merge(df_final_matches_selected_foul_committed,
                                          df_selected_cols[['match_id', 'competition', 'season']],
                                          on='match_id',
                                          how='left')
print(df_final_matches_selected_foul_committed.head())
df_final_matches_selected_foul_committed['field'] = "Foul_Committed"
# Out:
#      match_id  index  min_index  passes_in_sequence
# 399   3890268    454        451                   0
# 400   3890268    510        507                   1
# 401   3890268    640        638                   0
# 402   3890268    648        642                   2
# 403   3890268    761        731                   8
#
# First few rows of df_final_matches_selected_foul_committed with 'passes_in_sequence' column:
#                                      id  match_id       location  period  \
# 0  b6765dd6-5036-4b36-a2dc-4883429248de   3890268  [109.5, 45.9]       1
# 1  bfa5fb2b-742c-404d-b936-0b6a47c3ed18   3890268   [77.4, 35.0]       1
# 2  7c95cf04-993b-441a-8051-de57061cb9e9   3890268   [92.0, 65.0]       1
# 3  178a8f01-1244-482a-b1c2-603e7c348268   3890268   [33.4, 17.5]       1
# 4  71a82806-5ef9-4881-b843-33a708640507   3890268   [50.9, 16.3]       1
#
#    possession possession_team under_pressure      home_team  home_team_flag  \
# 0          21   Hertha Berlin            NaN  Hertha Berlin               1
# 1          24   Hertha Berlin            NaN  Hertha Berlin               1
# 2          34   Hertha Berlin            NaN  Hertha Berlin               1
# 3          35   Hertha Berlin            NaN  Hertha Berlin               1
# 4          43   Werder Bremen            NaN  Hertha Berlin               0
#
#   foul_committed_card  ...      x     y  counterpress index    play_pattern  \
# 0                 NaN  ...  109.5  45.9          True   454    Regular Play
# 1                 NaN  ...   77.4  35.0          True   510    Regular Play
# 2                 NaN  ...   92.0  65.0          True   640    Regular Play
# 3                 NaN  ...   33.4  17.5           NaN   648  From Free Kick
# 4                 NaN  ...   50.9  16.3           NaN   761    Regular Play
#
#   min_index  sequence length  passes_in_sequence              competition  \
# 0       451                3                   0  Germany - 1. Bundesliga
# 1       507                3                   1  Germany - 1. Bundesliga
# 2       638                2                   0  Germany - 1. Bundesliga
# 3       642                6                   2  Germany - 1. Bundesliga
# 4       731               30                   8  Germany - 1. Bundesliga
#
#       season
# 0  2015/2016
# 1  2015/2016
# 2  2015/2016
# 3  2015/2016
# 4  2015/2016
#
# [5 rows x 21 columns]

# %% [markdown]
# **df_foul_won** - on pause

# %%
selected_columns = [
    'id',
    'match_id',
    'location',
    'period',
    'possession',
    'possession_team',
    'under_pressure',
    'home_team',
    'home_team_flag',
    'foul_committed_card',
    'team',
    'x',
    'y',
    'counterpress',
    'index',
    'play_pattern'
]
# Check if the columns exist in the database
df_foul_won = new_dfs['df_foul_won']

existing_columns = [col for col in selected_columns if col in df_foul_won.columns]

# Create a new dataframe with only the existing selected columns
df_final_matches_selected_foul_won = df_foul_won[existing_columns]
df_final_matches_selected_foul_won
# Out:
#                                           id  match_id      location  period  \
# 3662    7c25c22a-275c-40a1-b2c6-399c3f5663d5   3890561  [68.1, 24.9]       1
# 3663    40613828-de11-4af8-babd-4a4874656e05   3890561   [28.8, 3.8]       1
# 3664    dad95065-2241-4a71-bed6-4d3ea2b5d65a   3890561   [14.7, 9.4]       1
# 3665    7234bf2e-fbaa-4cad-b414-b8fd14707d8b   3890561   [5.3, 58.7]       1
# 3666    961ce5da-3b1d-41cf-bbe9-46be8cae6540   3890561  [33.0, 49.3]       1
# ...                                      ...       ...           ...     ...
# 879642  e5e81120-1ed3-4e67-a1d6-94df869c9624   3890319  [88.7, 61.0]       2
# 879643  c2f7b724-b0a6-4c90-863b-42943009b291   3890319  [79.8, 42.5]       2
# 879644  df99191b-6302-4263-8ac8-8323eba9752d   3890319   [65.0, 6.7]       2
# 879645  7be2ad88-bafa-4b5f-bd55-09d5aa11240f   3890319  [81.4, 54.7]       2
# 879646  be0a880c-d177-46d8-979e-4cd6f9cf28c2   3890319  [85.2, 75.1]       2
#
#         possession possession_team under_pressure   home_team  home_team_flag  \
# 3662             7      Hoffenheim           True  Hoffenheim               1
# 3663            19      Schalke 04           True  Hoffenheim               0
# 3664            20      Schalke 04           True  Hoffenheim               0
# 3665            22      Schalke 04           True  Hoffenheim               0
# 3666            25      Hoffenheim           True  Hoffenheim               1
# ...            ...             ...            ...         ...             ...
# 879642         125       Wolfsburg           True   Wolfsburg               1
# 879643         146       Wolfsburg           True   Wolfsburg               1
# 879644         155     Hannover 96           True   Wolfsburg               0
# 879645         164     Hannover 96           True   Wolfsburg               0
# 879646         166       Wolfsburg           True   Wolfsburg               1
#
#        foul_committed_card         team     x     y counterpress  index  \
# 3662                   NaN   Hoffenheim  68.1  24.9          NaN    201
# 3663                   NaN   Schalke 04  28.8   3.8          NaN    478
# 3664                   NaN   Hoffenheim  14.7   9.4          NaN    499
# 3665                   NaN   Hoffenheim   5.3  58.7          NaN    559
# 3666                   NaN   Hoffenheim  33.0  49.3          NaN    602
# ...                    ...          ...   ...   ...          ...    ...
# 879642                 NaN    Wolfsburg  88.7  61.0          NaN   3086
# 879643                 NaN    Wolfsburg  79.8  42.5          NaN   3507
# 879644                 NaN  Hannover 96  65.0   6.7          NaN   3641
# 879645                 NaN  Hannover 96  81.4  54.7          NaN   3857
# 879646                 NaN    Wolfsburg  85.2  75.1          NaN   3874
#
#           play_pattern
# 3662      Regular Play
# 3663      Regular Play
# 3664    From Free Kick
# 3665    From Goal Kick
# 3666      Regular Play
# ...                ...
# 879642   From Throw In
# 879643   From Throw In
# 879644   From Throw In
# 879645  From Goal Kick
# 879646    Regular Play
#
# [7685 rows x 16 columns]

# %%
# Join df_final_matches_selected_foul_committed and df_final_matches on 'match_id' and 'possession'
df_merged = pd.merge(df_final_matches_selected_foul_won[['match_id', 'possession']],
                     df_final_matches[['match_id', 'possession', 'index']],
                     on=['match_id', 'possession'],
                     how='inner')

# Find the minimum index for each match_id and possession combination
df_min_index = df_merged.groupby(['match_id', 'possession'])['index'].min().reset_index()
df_min_index.rename(columns={'index': 'min_index'}, inplace=True)

# Join the minimum index back onto df_final_matches_selected_foul_committed
df_final_matches_selected_foul_won = pd.merge(df_final_matches_selected_foul_won,
                                          df_min_index,
                                          on=['match_id', 'possession'],
                                          how='left')

df_final_matches_selected_foul_won
# Out:
#                                         id  match_id      location  period  \
# 0     7c25c22a-275c-40a1-b2c6-399c3f5663d5   3890561  [68.1, 24.9]       1
# 1     40613828-de11-4af8-babd-4a4874656e05   3890561   [28.8, 3.8]       1
# 2     dad95065-2241-4a71-bed6-4d3ea2b5d65a   3890561   [14.7, 9.4]       1
# 3     7234bf2e-fbaa-4cad-b414-b8fd14707d8b   3890561   [5.3, 58.7]       1
# 4     961ce5da-3b1d-41cf-bbe9-46be8cae6540   3890561  [33.0, 49.3]       1
# ...                                    ...       ...           ...     ...
# 7680  e5e81120-1ed3-4e67-a1d6-94df869c9624   3890319  [88.7, 61.0]       2
# 7681  c2f7b724-b0a6-4c90-863b-42943009b291   3890319  [79.8, 42.5]       2
# 7682  df99191b-6302-4263-8ac8-8323eba9752d   3890319   [65.0, 6.7]       2
# 7683  7be2ad88-bafa-4b5f-bd55-09d5aa11240f   3890319  [81.4, 54.7]       2
# 7684  be0a880c-d177-46d8-979e-4cd6f9cf28c2   3890319  [85.2, 75.1]       2
#
#       possession possession_team under_pressure   home_team  home_team_flag  \
# 0              7      Hoffenheim           True  Hoffenheim               1
# 1             19      Schalke 04           True  Hoffenheim               0
# 2             20      Schalke 04           True  Hoffenheim               0
# 3             22      Schalke 04           True  Hoffenheim               0
# 4             25      Hoffenheim           True  Hoffenheim               1
# ...          ...             ...            ...         ...             ...
# 7680         125       Wolfsburg           True   Wolfsburg               1
# 7681         146       Wolfsburg           True   Wolfsburg               1
# 7682         155     Hannover 96           True   Wolfsburg               0
# 7683         164     Hannover 96           True   Wolfsburg               0
# 7684         166       Wolfsburg           True   Wolfsburg               1
#
#      foul_committed_card         team     x     y counterpress  index  \
# 0                    NaN   Hoffenheim  68.1  24.9          NaN    201
# 1                    NaN   Schalke 04  28.8   3.8          NaN    478
# 2                    NaN   Hoffenheim  14.7   9.4          NaN    499
# 3                    NaN   Hoffenheim   5.3  58.7          NaN    559
# 4                    NaN   Hoffenheim  33.0  49.3          NaN    602
# ...                  ...          ...   ...   ...          ...    ...
# 7680                 NaN    Wolfsburg  88.7  61.0          NaN   3086
# 7681                 NaN    Wolfsburg  79.8  42.5          NaN   3507
# 7682                 NaN  Hannover 96  65.0   6.7          NaN   3641
# 7683                 NaN  Hannover 96  81.4  54.7          NaN   3857
# 7684                 NaN    Wolfsburg  85.2  75.1          NaN   3874
#
#         play_pattern  min_index
# 0       Regular Play        192
# 1       Regular Play        475
# 2     From Free Kick        479
# 3     From Goal Kick        519
# 4       Regular Play        599
# ...              ...        ...
# 7680   From Throw In       3072
# 7681   From Throw In       3495
# 7682   From Throw In       3629
# 7683  From Goal Kick       3838
# 7684    Regular Play       3862
#
# [7685 rows x 17 columns]

# %%
df_final_matches_selected_foul_won = df_final_matches_selected_foul_won.sort_values(by=['match_id', 'possession', 'index'])
df_final_matches_selected_foul_won['sequence length'] = df_final_matches_selected_foul_won['index'] - df_final_matches_selected_foul_won['min_index']

# Initialize a list to store the counts for each shot
pass_counts = []

# Iterate through each row in df_final_matches_selected_foul_committed
for index, row in df_final_matches_selected_foul_won.iterrows():
    match_id = row['match_id']
    shot_index = row['index']
    min_index = row['min_index']

    # Filter df_final_matches for the current match_id and the relevant index range
    relevant_events = df_final_matches[
        (df_final_matches['match_id'] == match_id) &
        (df_final_matches['index'] >= min_index) &
        (df_final_matches['index'] <= shot_index)
    ]

    # Count the number of rows where 'type' is 'Pass' in the filtered events
    count_passes = relevant_events[relevant_events['type'] == 'Pass'].shape[0]

    # Append the count to the list
    pass_counts.append(count_passes)

# Add the pass counts as a new column to df_final_matches_selected_foul_committed
df_final_matches_selected_foul_won['passes_in_sequence'] = pass_counts

print(df_final_matches_selected_foul_won[['match_id', 'index', 'min_index', 'passes_in_sequence']].head())
print("\nFirst few rows of df_final_matches_selected_foul_committed with 'passes_in_sequence' column:")

df_final_matches_selected_foul_won = pd.merge(df_final_matches_selected_foul_won,
                                          df_selected_cols[['match_id', 'competition', 'season']],
                                          on='match_id',
                                          how='left')
print(df_final_matches_selected_foul_won.head())
df_final_matches_selected_foul_won['field'] = "Foul_Won"
# Out:
#      match_id  index  min_index  passes_in_sequence
# 384   3890268    455        451                   0
# 385   3890268    511        507                   1
# 386   3890268    641        638                   0
# 387   3890268    649        642                   2
# 388   3890268    762        731                   8
#
# First few rows of df_final_matches_selected_foul_committed with 'passes_in_sequence' column:
#                                      id  match_id      location  period  \
# 0  b982b850-ab91-44b7-aa17-f71de69a4f47   3890268  [10.6, 34.2]       1
# 1  85b75f93-8c35-4651-a42c-c43756e81917   3890268  [42.7, 45.1]       1
# 2  b2fa81a1-e163-4012-a65f-9d4ef69ce5d9   3890268  [28.1, 15.1]       1
# 3  fb01cbb2-35ca-4bac-ad85-423a4f77f877   3890268  [86.7, 62.6]       1
# 4  fdd69cd0-fbd2-4cc6-83fa-ed892e8b2d58   3890268  [69.2, 63.8]       1
#
#    possession possession_team under_pressure      home_team  home_team_flag  \
# 0          21   Hertha Berlin           True  Hertha Berlin               1
# 1          24   Hertha Berlin           True  Hertha Berlin               1
# 2          34   Hertha Berlin           True  Hertha Berlin               1
# 3          35   Hertha Berlin           True  Hertha Berlin               1
# 4          43   Werder Bremen           True  Hertha Berlin               0
#
#   foul_committed_card  ...     x     y  counterpress index    play_pattern  \
# 0                 NaN  ...  10.6  34.2           NaN   455    Regular Play
# 1                 NaN  ...  42.7  45.1           NaN   511    Regular Play
# 2                 NaN  ...  28.1  15.1           NaN   641    Regular Play
# 3                 NaN  ...  86.7  62.6           NaN   649  From Free Kick
# 4                 NaN  ...  69.2  63.8           NaN   762    Regular Play
#
#   min_index  sequence length  passes_in_sequence              competition  \
# 0       451                4                   0  Germany - 1. Bundesliga
# 1       507                4                   1  Germany - 1. Bundesliga
# 2       638                3                   0  Germany - 1. Bundesliga
# 3       642                7                   2  Germany - 1. Bundesliga
# 4       731               31                   8  Germany - 1. Bundesliga
#
#       season
# 0  2015/2016
# 1  2015/2016
# 2  2015/2016
# 3  2015/2016
# 4  2015/2016
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Combining Event Data for Analysis
#
# This section combines the dataframes created for each specific event type (Duels, 50/50s, Dispossessed, Foul Committed, and Foul Won) into a single DataFrame for further analysis related to referee decisions and game events.

# %%
# List of dataframes to join
referee_analysis = [
df_final_matches_selected_foul_won,
df_final_matches_selected_foul_committed,
df_final_matches_selected_dispossessed,
df_final_matches_selected_duel,
df_50
]

df_referee_analysis = pd.concat(referee_analysis, ignore_index=True)

# %% [markdown]
# ## Saving the Combined Analysis Data
#
# This section saves the combined DataFrame containing the analysis of various event types (`df_referee_analysis`) to a CSV file in your Google Drive for future use or further analysis.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# Specify the path where you want to save the CSV file in your Google Drive

file_path = f'/content/drive/My Drive/referee_analysis{b}.csv'
# Save the DataFrame to a CSV file
df_referee_analysis.to_csv(file_path, index=False)
print(f"DataFrame saved successfully to {file_path}")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-3291653226.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3
#       4 # Specify the path where you want to save the CSV file in your Google Drive
#       5
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful
